# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
data = pd.read_csv('used-car.csv')

# %%
data1 = data[data['Transmission'] =='Automatic']

# %%
x = np.array(data1.loc[:,'Year']).reshape(-1,1)
y = np.array(data1.loc[:,'Kilometers_Driven']).reshape(-1,1)
plt.figure(figsize=[10,10])
plt.scatter(x=x,y=y)
plt.xlabel('Year')
plt.ylabel('Kilometers_Driven')
plt.show()

# %%
from sklearn.linear_model import LinearRegression
reg = LinearRegression()
predict_space = np.linspace(min(x), max(x)).reshape(-1,1)
reg.fit(x,y)
predicted = reg.predict(predict_space)
print('R^2 score: ',reg.score(x, y))
plt.plot(predict_space, predicted, color='black', linewidth=3)
plt.scatter(x=x,y=y)
plt.xlabel('Year')
plt.ylabel('Kilometers_Driven')
plt.show()
# Out:
# R^2 score:  0.3182217694209858
